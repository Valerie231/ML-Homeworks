# %% [markdown]
# <a href="https://colab.research.google.com/github/Valerie231/ML_homeworks/blob/main/HW_2_2_%D0%A4%D1%83%D0%BD%D0%BA%D1%86%D1%96%D1%97_%D1%96_%D0%BF%D0%BE%D1%85%D1%96%D0%B4%D0%BD%D1%96.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Домашні завдання на відпрацювання поняття функції та її похідної
#
# 1. Задана функція залежності оцінки від кількості годин, витрачених на навчання: $ f(x) = 10x - 5 $.
#   1. З допомогою Python обчисліть похідну цієї функції.
#   2. Використовуйте бібліотеку `matplotlib` для побудови графіків функції та її похідної в діапазоні значень від 0 до 10 годин. Проаналізуйте, як зміна кількості годин вивчення впливає на оцінку.

# %%
import sympy as sp

# %%
x = sp.symbols('x')
f = 10*x - 5

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 10, 20)
f = 10*x - 5
df = [10 for x in x] # Похідна f'(x) = 10

# Створення графіку
plt.figure(figsize=(10, 5))
plt.plot(x, f, label='f(x) = 10*x - 5', color='blue')
plt.plot(x, df, label='f(x) = 10', color='green')

# Додавання легенди, міток та заголовка
plt.title("Графік функції та її похідної")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# Кожна додаткова година підвищує оцінку на 10 балів.

# %% [markdown]
# 2. Використовуючи Python і `SymPy`, обчисліть похідні для функцій $ f(x) = \sin(x) $ та $ f(x) = \ln(x) $. Зобразіть ці функції та їхні похідні за допомогою `matplotlib`.

# %%
x = sp.symbols('x')

f = sp.sin(x)
df = sp.diff(f, x)

f1 = sp.ln(x)
df1 = sp.diff(f1, x)

# %%
print('Derivative of f(x) = sin(x):', df)
print('Derivative of f(x) = ln(x):', df1)
# Out:
# Derivative of f(x) = sin(x): cos(x)
# Derivative of f(x) = ln(x): 1/x

# %%
x = np.linspace(0, 2 * np.pi, 100)

plt.figure(figsize =(10, 8))
plt.plot(x, np.sin(x), label='f(x) = sin(x)', color='blue')
plt.plot(x, np.cos(x), label='f(x) = cos(x)', color='green')

plt.title("Графік функції та її похідної")
plt.xlabel("x")
plt.ylabel("y")

plt.legend()
plt.grid(True)
plt.show()

# %%
x = np.linspace(0, 5, 100)

plt.figure(figsize =(10, 8))
plt.plot(x, np.log(x), label='f(x) = ln(x)', color='blue')
plt.plot(x, 1/x, label='f(x) = 1/x', color='green')

plt.title("Графік функції та її похідної")
plt.xlabel("x")
plt.ylabel("y")

plt.legend()
plt.grid(True)
plt.show()
# Out:
# <ipython-input-56-e818918712ce>:4: RuntimeWarning: divide by zero encountered in log
#   plt.plot(x, np.log(x), label='f(x) = ln(x)', color='blue')
# <ipython-input-56-e818918712ce>:5: RuntimeWarning: divide by zero encountered in divide
#   plt.plot(x, 1/x, label='f(x) = 1/x', color='green')

# %% [markdown]
# 3. Загальні витрати компанії від обсягу виробництва задані функцією $ f(x) = x^2 - 5x + 1 $, де $ x $ — кількість вироблених одиниць. Обчисліть похідну цієї функції з допомогою SymPy та візуалізуйте значення функції і її похідної на відрізку від 0 до 100.

# %%
x = sp.symbols('x')

f = x**2 - 5*x + 1
sp.diff(f, x)
# Out:
# 2*x - 5

# %%
x = np.linspace(0, 100, 100)
f = x**2 - 5*x + 1
df = 2*x - 5

plt.figure(figsize=(10,5))
plt.plot(x, f, label='f(x) = x^2 - 5x + 1', color = 'blue')
plt.plot(x, df, label='f(x) = 2x - 5', color = 'green')
plt.grid(True)
plt.legend()
